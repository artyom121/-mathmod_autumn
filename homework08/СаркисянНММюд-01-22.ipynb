# %%
##Сакрсиян Артем НММбд-01-22

# %%
Задача 1

Проведите анализ скорости работы всех рассмотренных алгоритмов 

поиска на массиве, состоящем из 100 случайных значений (значения от 1 до 1000). 

В качестве искомого возьмите элемент, индекс которого будет 5.

# %%
import time
import random
def linear_search(arr, x):
    for i in range(len(arr)):
        if arr[i] == x:
            return i
    return -1

def binary_search(arr, x):
    left, right = 0, len(arr) - 1
    while left <= right:
        mid = (left + right) // 2
        if arr[mid] == x:
            return mid
        elif arr[mid] < x:
            left = mid + 1
        else:
            right = mid - 1
    return -1

def fibonacci_sort(arr):
    def fibonacci(n):
        fib = [0, 1]
        while fib[-1] < n:
            fib.append(fib[-1] + fib[-2])
        return fib

    fib = fibonacci(max(arr))
    i = len(fib) - 1
    while arr:
        while fib[i] > len(arr):
            i -= 1
        max_val = max(arr)
        if max_val == fib[i]:
            i -= 1
            continue
        idx = arr.index(max_val)
        arr[-1], arr[idx] = arr[idx], arr[-1]
        arr.pop()

def jump_search(arr, x):
    n = len(arr)
    step = int(n**0.5)
    prev = 0
    while arr[min(step, n)-1] < x:
        prev = step
        step += int(n**0.5)
        if prev >= n:
            return -1
    while arr[prev] < x:
        prev += 1
        if prev == min(step, n):
            return -1
    if arr[prev] == x:
        return prev
    return -1

random.seed(42)
arr = random.sample(range(1, 1001), 100)

start_time = time.perf_counter()
linear_search_index = linear_search(arr, arr[5])
end_time = time.perf_counter()
linear_search_time = end_time - start_time

arr.sort()
start_time = time.perf_counter()
binary_search_index = binary_search(arr, arr[5])
end_time = time.perf_counter()
binary_search_time = end_time - start_time

start_time = time.perf_counter()
fibonacci_sort(arr.copy())
end_time = time.perf_counter()
fibonacci_sort_time = end_time - start_time

start_time = time.perf_counter()
jump_search_index = jump_search(arr, arr[5])
end_time = time.perf_counter()
jump_search_time = end_time - start_time

print("Искомый элемент:", arr[5])
print("Индекс элемента (линейный поиск):", linear_search_index)
print("Время выполнения линейного поиска:", linear_search_time)
print("Индекс элемента (бинарный поиск):", binary_search_index)
print("Время выполнения бинарного поиска:", binary_search_time)
print("Время выполнения сортировки методом Фибоначчи:", fibonacci_sort_time)
print("Индекс элемента (поиск методом прыжка):", jump_search_index)
print("Время выполнения поиска методом прыжка:", jump_search_time)
# Out:
# Искомый элемент: 45
# Индекс элемента (линейный поиск): 5
# Время выполнения линейного поиска: 5.4700001783203334e-05
# Индекс элемента (бинарный поиск): 5
# Время выполнения бинарного поиска: 5.439999949885532e-05
# Время выполнения сортировки методом Фибоначчи: 0.000244400005612988
# Индекс элемента (поиск методом прыжка): 5
# Время выполнения поиска методом прыжка: 5.5000004067551345e-05

# %%
Задача 2

Проведите анализ скорости работы всех рассмотренных алгоритмов 

поиска на массиве, состоящем из 100 случайных значений (значения от 1 до 1000). 

В качестве искомого возьмите элемент, индекс которого будет 95.

# %%
import time
import random
def linear_search(arr, x):
    for i in range(len(arr)):
        if arr[i] == x:
            return i
    return -1

def binary_search(arr, x):
    left, right = 0, len(arr) - 1
    while left <= right:
        mid = (left + right) // 2
        if arr[mid] == x:
            return mid
        elif arr[mid] < x:
            left = mid + 1
        else:
            right = mid - 1
    return -1

def fibonacci_sort(arr):
    def fibonacci(n):
        fib = [0, 1]
        while fib[-1] < n:
            fib.append(fib[-1] + fib[-2])
        return fib

    fib = fibonacci(max(arr))
    i = len(fib) - 1
    while arr:
        while fib[i] > len(arr):
            i -= 1
        max_val = max(arr)
        if max_val == fib[i]:
            i -= 1
            continue
        idx = arr.index(max_val)
        arr[-1], arr[idx] = arr[idx], arr[-1]
        arr.pop()

def jump_search(arr, x):
    n = len(arr)
    step = int(n**0.5)
    prev = 0
    while arr[min(step, n)-1] < x:
        prev = step
        step += int(n**0.5)
        if prev >= n:
            return -1
    while arr[prev] < x:
        prev += 1
        if prev == min(step, n):
            return -1
    if arr[prev] == x:
        return prev
    return -1

random.seed(42)
arr = random.sample(range(1, 1001), 100)

start_time = time.perf_counter()
linear_search_index = linear_search(arr, arr[95])
end_time = time.perf_counter()
linear_search_time = end_time - start_time

arr.sort()
start_time = time.perf_counter()
binary_search_index = binary_search(arr, arr[95])
end_time = time.perf_counter()
binary_search_time = end_time - start_time

start_time = time.perf_counter()
fibonacci_sort(arr.copy())
end_time = time.perf_counter()
fibonacci_sort_time = end_time - start_time

start_time = time.perf_counter()
jump_search_index = jump_search(arr, arr[95])
end_time = time.perf_counter()
jump_search_time = end_time - start_time

print("Искомый элемент:", arr[95])
print("Индекс элемента (линейный поиск):", linear_search_index)
print("Время выполнения линейного поиска:", linear_search_time)
print("Индекс элемента (бинарный поиск):", binary_search_index)
print("Время выполнения бинарного поиска:", binary_search_time)
print("Время выполнения сортировки методом Фибоначчи:", fibonacci_sort_time)
print("Индекс элемента (поиск методом прыжка):", jump_search_index)
print("Время выполнения поиска методом прыжка:", jump_search_time)
# Out:
# Искомый элемент: 965
# Индекс элемента (линейный поиск): 95
# Время выполнения линейного поиска: 5.769999552285299e-05
# Индекс элемента (бинарный поиск): 95
# Время выполнения бинарного поиска: 4.9700000090524554e-05
# Время выполнения сортировки методом Фибоначчи: 0.00029770000401185825
# Индекс элемента (поиск методом прыжка): 95
# Время выполнения поиска методом прыжка: 5.8999998145736754e-05

# %%
Задача 3

Сделайте выводы по скорости работы алгоритмов поиска в разных условиях из 1 и 2 задач.

Постройте 2 графика сравнения этих скоростей.

# %%
import matplotlib.pyplot as plt

time_dict = {'linear for 5':5.47,
              'binary for 5':5.439,
              'jump for 5':5.5,
              'fib for 5':0.0002}

plt.figure(figsize=(8,6))
plt.bar(time_dict.keys(), time_dict.values())
plt.show()

# %%
import matplotlib.pyplot as plt

time_dict2 = {'linear for 5':5.76,
              'binary for 5':4.97,
              'jump for 5':5.89,
              'fib for 5':0.0002}

plt.figure(figsize=(8,6))
plt.bar(time_dict2.keys(), time_dict2.values())
plt.show()

# %%
Задача 4

Проведите анализ скорости работы всех рассмотренных алгоритмов 

сортировки на массиве, состоящем из 100 значений (значения массива 

должны быть последовательными от 1 до 100).

# %%
import time
import random
import matplotlib.pyplot as plt

def measure_sorting_time(sort_func, array):
    start_time = time.perf_counter()
    sorted_array = sort_func(array)
    end_time = time.perf_counter()
    return sorted_array, end_time - start_time

def bubble_sort(array):
    n = len(array)
    for i in range(n):
        for j in range(0, n-i-1):
            if array[j] > array[j+1]:
                array[j], array[j+1] = array[j+1], array[j]
    return array

def selection_sort(array):
    n = len(array)
    for i in range(n):
        min_idx = i
        for j in range(i+1, n):
            if array[j] < array[min_idx]:
                min_idx = j
        array[i], array[min_idx] = array[min_idx], array[i]
    return array

def insertion_sort(array):
    n = len(array)
    for i in range(1, n):
        key = array[i]
        j = i - 1
        while j >= 0 and key < array[j]:
            array[j + 1] = array[j]
            j -= 1
        array[j + 1] = key
    return array

def merge_sort(array):
    if len(array) > 1:
        mid = len(array) // 2
        left_half = array[:mid]
        right_half = array[mid:]

        merge_sort(left_half)
        merge_sort(right_half)

        i = j = k = 0

        while i < len(left_half) and j < len(right_half):
            if left_half[i] < right_half[j]:
                array[k] = left_half[i]
                i += 1
            else:
                array[k] = right_half[j]
                j += 1
            k += 1

        while i < len(left_half):
            array[k] = left_half[i]
            i += 1
            k += 1

        while j < len(right_half):
            array[k] = right_half[j]
            j += 1
            k += 1

    return array

def partition(array, low, high):
    pivot = array[high]
    i = low - 1
    for j in range(low, high):
        if array[j] <= pivot:
            i += 1
            array[i], array[j] = array[j], array[i]
    array[i + 1], array[high] = array[high], array[i + 1]
    return i + 1

def quick_sort(array, low, high):
    if low < high:
        pi = partition(array, low, high)
        quick_sort(array, low, pi - 1)
        quick_sort(array, pi + 1, high)
    return array

array = list(range(1, 101))

random.shuffle(array)

bubble_sorted_array, bubble_sort_time = measure_sorting_time(bubble_sort, array.copy())
selection_sorted_array, selection_sort_time = measure_sorting_time(selection_sort, array.copy())
insertion_sorted_array, insertion_sort_time = measure_sorting_time(insertion_sort, array.copy())
merge_sorted_array, merge_sort_time = measure_sorting_time(merge_sort, array.copy())
quick_sorted_array, quick_sort_time = measure_sorting_time(lambda arr: quick_sort(arr, 0, len(arr) - 1), array.copy())

print("Время выполнения сортировки пузырьком:", bubble_sort_time)
print("Время выполнения сортировки выбором:", selection_sort_time)
print("Время выполнения сортировки вставками:", insertion_sort_time)
print("Время выполнения сортировки слиянием:", merge_sort_time)
print("Время выполнения быстрой сортировки:", quick_sort_time)
# Out:
# Время выполнения сортировки пузырьком: 0.0004307999915909022
# Время выполнения сортировки выбором: 0.00031380000291392207
# Время выполнения сортировки вставками: 0.0003053999971598387
# Время выполнения сортировки слиянием: 0.0002415000053588301
# Время выполнения быстрой сортировки: 0.00012879999121651053

# %%
Задача 5

Проведите анализ скорости работы всех рассмотренных алгоритмов 

сортировки на массиве, состоящем из 100 значений (значения массива 

должны иметь обратную последовательность от 100 до 1).

# %%
import time
import random

# Функция для измерения времени выполнения алгоритма сортировки
def measure_sorting_time(sort_func, array):
    start_time = time.perf_counter()
    sorted_array = sort_func(array)
    end_time = time.perf_counter()
    return sorted_array, end_time - start_time

# Реализация алгоритмов сортировки
def bubble_sort(array):
    n = len(array)
    for i in range(n):
        for j in range(0, n-i-1):
            if array[j] > array[j+1]:
                array[j], array[j+1] = array[j+1], array[j]
    return array

def selection_sort(array):
    n = len(array)
    for i in range(n):
        min_idx = i
        for j in range(i+1, n):
            if array[j] < array[min_idx]:
                min_idx = j
        array[i], array[min_idx] = array[min_idx], array[i]
    return array

def insertion_sort(array):
    n = len(array)
    for i in range(1, n):
        key = array[i]
        j = i - 1
        while j >= 0 and key < array[j]:
            array[j + 1] = array[j]
            j -= 1
        array[j + 1] = key
    return array

def merge_sort(array):
    if len(array) > 1:
        mid = len(array) // 2
        left_half = array[:mid]
        right_half = array[mid:]

        merge_sort(left_half)
        merge_sort(right_half)

        i = j = k = 0

        while i < len(left_half) and j < len(right_half):
            if left_half[i] < right_half[j]:
                array[k] = left_half[i]
                i += 1
            else:
                array[k] = right_half[j]
                j += 1
            k += 1

        while i < len(left_half):
            array[k] = left_half[i]
            i += 1
            k += 1

        while j < len(right_half):
            array[k] = right_half[j]
            j += 1
            k += 1

    return array

def partition(array, low, high):
    pivot = array[high]
    i = low - 1
    for j in range(low, high):
        if array[j] <= pivot:
            i += 1
            array[i], array[j] = array[j], array[i]
    array[i + 1], array[high] = array[high], array[i + 1]
    return i + 1

def quick_sort(array, low, high):
    if low < high:
        pi = partition(array, low, high)
        quick_sort(array, low, pi - 1)
        quick_sort(array, pi + 1, high)
    return array
    
array = list(range(100, 0, -1))

bubble_sorted_array, bubble_sort_time = measure_sorting_time(bubble_sort, array.copy())
selection_sorted_array, selection_sort_time = measure_sorting_time(selection_sort, array.copy())
insertion_sorted_array, insertion_sort_time = measure_sorting_time(insertion_sort, array.copy())
merge_sorted_array, merge_sort_time = measure_sorting_time(merge_sort, array.copy())
quick_sorted_array, quick_sort_time = measure_sorting_time(lambda arr: quick_sort(arr, 0, len(arr) - 1), array.copy())

print("Время выполнения сортировки пузырьком:", bubble_sort_time)
print("Время выполнения сортировки выбором:", selection_sort_time)
print("Время выполнения сортировки вставками:", insertion_sort_time)
print("Время выполнения сортировки слиянием:", merge_sort_time)
print("Время выполнения быстрой сортировки:", quick_sort_time)
# Out:
# Время выполнения сортировки пузырьком: 0.0006309000018518418
# Время выполнения сортировки выбором: 0.000264899994363077
# Время выполнения сортировки вставками: 0.0004496000037761405
# Время выполнения сортировки слиянием: 0.00015690000145696104
# Время выполнения быстрой сортировки: 0.00041429999691899866

# %%
Задача 6

Сделайте выводы по скорости работы алгоритмов сортировки в разных условиях из 4 и 5 задач.

Постройте 2 графика сравнения этих скоростей.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
time_dict2 = {'buble':0.0004,
              'vbor':0.00031,
              'vstavka':0.0003,
              'sliyanie':0.00024,
              'sortirovka':0.00012}

plt.bar(time_dict2.keys(), time_dict2.values())
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
time_dict3 = {'buble1':0.00063,
              'vbor1':0.00026,
              'vstavka1':0.00044,
              'sliyanie1':0.00015,
              'sortirovka1':0.00041}

plt.bar(time_dict3.keys(), time_dict3.values())
plt.show()
